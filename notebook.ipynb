# %% [markdown]
# Olá estudante!
#
# Me chamo Rafael Meirelles e irei revisar o seu projeto hoje e em eventuais futuras submissões até que ele cumpra todos os requisitos para o aceite.
# Conte comigo nessa jornada e não se preocupe se precisar ajustar alguns detalhes, é parte do processo e fundamental para que você exercite os conceitos que vem aprendendo e assim melhore a qualidade dos seus códigos e análises.
#
# **Peço que mantenha e não altere os comentários que eu fizer por aqui para que possamos nos localizar posteriormente, ok?**
#
# Mais uma coisa, vamos utilizar um código de cores para você entender os meus feedbacks no seu notebook. Funciona assim:
#
#
# <div class="alert alert-danger">
# <strong>Vermelho</strong>
#
# Erro que precisa ser consertado, caso contrário, seu projeto não pode ser aceito
#
# </div>
#
# <div class="alert alert-warning">
# <strong>Amarelo</strong>
#
# Alerta de um erro não crítco, mas que pode ser corrigido para melhoria geral no seu código/análise
#
# </div>
#
# <div class="alert alert-success">
# <strong>Verde</strong>
#
# Elogios
# </div>
#
# <div class="alert alert-info">
# <strong>Comentário do estudante</strong>
#
# Use uma caixa azul como essa para eventuais comentários que você gostaria de fazer para mim.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <strong>Comentário do revisor v1</strong>
#
# Estamos no caminho certo com essa versão, mas retocar os pontos indicados abaixo nos fará chegar em um resultado ainda mais incrível.
#
# Conte comigo para ajudá-lo (a) em qualquer questão que possa vir a ter! Lembre-se de usar as caixas azuis para se comunicar comigo.
#
# Até breve.
# </div>

# %% [markdown]
# # Vamos encher o carrinho!

# %% [markdown]
# # Introdução
#
# O Instacart é uma plataforma de entrega de supermercado onde os clientes podem fazer um pedido no supermercado e depois receber sua compra, semelhante ao funcionamento do Uber Eats e do iFood. O conjunto de dados que fornecemos foi modificado a partir do original. Reduzimos o tamanho dele para que seus cálculos sejam executados mais rapidamente e incluímos valores ausentes e duplicados. Também tivemos o cuidado de preservar as distribuições dos dados originais quando fizemos as alterações.
#
# Você precisa completar três etapas. Para cada uma delas, escreva uma breve introdução descrevendo como você pretende concluir a etapa e justifique suas decisões em parágrafos explicativos a medida que você avança na solução. Escreva também uma conclusão para resumir suas conclusões e escolhas.

# %% [markdown]
# ## Dicionário de dados
#
# Há cinco tabelas no conjunto de dados, e você vai precisar usar todas elas para pré-processar seus dados e fazer AED. Abaixo está um dicionário que lista as colunas de cada tabela e descreve os dados contidos nelas.
#
# - `instacart_orders.csv`: cada linha corresponde a um pedido no aplicativo da Instacart
#     - `'order_id'`: é o número que identifica cada pedido de forma exclusiva
#     - `'user_id'`: é o número de identificação exclusivo da conta de cada cliente
#     - `'order_number'`: é o número de vezes que o cliente fez um pedido
#     - `'order_dow'`: é o dia da semana em que o pedido foi feito (0 é domingo)
#     - `'order_hour_of_day'`: é a hora do dia em que o pedido foi feito
#     - `'days_since_prior_order'`: é o número de dias desde que o cliente fez seu pedido anterior
#
#
#
#
# - `products.csv`: cada linha corresponde a um produto exclusivo que os clientes podem comprar
#     - `'product_id'`: é o número de identificação unívoco de cada produto
#     - `'product_name'`: é o nome do produto
#     - `'aisle_id'`: é o número de identificação exclusivo de cada categoria de corredor do supermercado
#     - `'department_id'`: é o número de identificação exclusivo de cada categoria de departamento do supermercado
#
#
#
#
# -	`order_products.csv`: cada linha corresponde a um item incluído em um pedido
#     -	`'order_id'`: é o número que identifica cada pedido de forma exclusiva
#     -	`'product_id'`: é o número de identificação exclusivo de cada produto
#     -	`'add_to_cart_order'`: é a ordem sequencial em que cada item foi colocado no carrinho
#     -	`'reordered'`: 0 se o cliente nunca comprou o produto antes, 1 se já o comprou
#
#
#
#
# -	`aisles.csv`
#     -	`'aisle_id'`: é o número de identificação exclusivo de cada categoria de corredor do supermercado
#     -	`'aisle'`: é o nome do corredor
#
#
#
# -	`departments.csv`
#     -	`'department_id'`: é o número de identificação exclusivo de cada categoria de departamento do supermercado
#     -	`'department'`: é o nome do departamento

# %% [markdown]
# # Etapa 1. Visão geral dos dados
#
# Leia os arquivos de dados (/datasets/instacart_orders.csv, /datasets/products.csv, /datasets/aisles.csv, /datasets/departments.csv e /datasets/order_products.csv) com `pd.read_csv()` usando os parâmetros apropriados para fazer isso corretamente. Verifique as informações para cada DataFrame criado.

# %% [markdown]
# ## Plano de solução
#
# Escreva aqui seu plano para a Etapa 2. Visão geral dos dados

# %%
import pandas as pd# Importe as bibliotecas

# %%
df_orders       = pd.read_csv('/datasets/instacart_orders.csv',sep=';')
df_products     = pd.read_csv('/datasets/products.csv',sep=';')
df_aisles       = pd.read_csv('/datasets/aisles.csv',sep=';')
df_departments  = pd.read_csv('/datasets/departments.csv',sep=';')
df_order_prod   = pd.read_csv('/datasets/order_products.csv',sep=';')

# %%
df_orders.info() # imprima as informações sobre o DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB

# %%
df_products.info()# imprima as informações sobre o DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
df_aisles.info() # imprima as informações sobre o DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
df_departments.info()# imprima as informações sobre o DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes

# %%
df_order_prod.info()# imprima as informações sobre o DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  float64
#  3   reordered          int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB

# %% [markdown]
# ## Conclusões
#
# Escreva aqui suas conclusões intermediárias da Etapa 1. Visão geral dos dados

# %% [markdown]
# # Etapa 2. Preparação de dados
#
# Faça o pré-processamento dos dados da seguinte maneira:
#
# -	Verifique e corrija os tipos de dados (por exemplo, certifique-se de que as colunas de ID sejam números inteiros)
# -	Identifique e preencha valores ausentes
# -	Identifique e remova valores duplicados
#
# Certifique-se de explicar que tipos de valores ausentes e duplicados você encontrou, como você os preencheu ou removeu, por que escolheu esses métodos e por que você acha que esses valores ausentes e duplicados estavam presentes no conjunto de dados.

# %% [markdown]
# ## Plano de solução
#
# Escreva aqui seu plano para a Etapa 2. Preparação de dados

# %% [markdown]
# ## Encontre e remova valores duplicados (e descreva por que você está fazendo suas escolhas)

# %% [markdown]
# ### DataFrame `instacart_orders`

# %%
df_orders.duplicated() # Verificar se há pedidos duplicados
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 478962    False
# 478963    False
# 478964    False
# 478965    False
# 478966    False
# Length: 478967, dtype: bool

# %% [markdown]
# Há linhas duplicadas? Se sim, o que elas têm em comum?

# %%
# Com base nas suas conclusões,

# verifique todos os pedidos feitos às 2h da manhã nas quartas-feiras

df_wed_2am = df_orders[
    (df_orders['order_hour_of_day'] == 2) &
    (df_orders['order_dow'] == 3)
    ]

# %% [markdown]
# O que esse resultado quer dizer?

# %%
df_orders.drop_duplicates (inplace=True) # Remova pedidos duplicados

# %%
df_orders.duplicated() # Verifique as linhas duplicadas mais uma vez
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 478962    False
# 478963    False
# 478964    False
# 478965    False
# 478966    False
# Length: 478952, dtype: bool

# %%
print (df_orders['order_id']) # Verifique novamente apenas os IDs de pedidos duplicados
# Out:
# 0         1515936
# 1         1690866
# 2         1454967
# 3         1768857
# 4         3007858
#            ...
# 478962    3210681
# 478963    3270802
# 478964     885349
# 478965     216274
# 478966    2071924
# Name: order_id, Length: 478952, dtype: int64

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
#
# Haviam linhas duplicadas que foram removidas e agora o DataFrame contém apenas pedidos únicos.
#
# O filtro de “2h da manhã nas quartas” permite entender hábitos de consumo em horários específicos, o que pode ajudar em análises de comportamento ou logística

# %% [markdown]
# ### DataFrame `products`

# %%
df_products.duplicated()  # Verifique se há linhas completamente duplicadas
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# 49693    False
# Length: 49694, dtype: bool

# %%
df_products['product_id'].duplicated() # Verifique apenas IDs dos produtos duplicados
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# 49693    False
# Name: product_id, Length: 49694, dtype: bool

# %%
df_products[df_products['product_name'].str.lower().duplicated()] # Verifique apenas nomes de produtos duplicados (converta os nomes para minúsculas para uma comparação melhor)
# Out:
#        product_id                                     product_name  aisle_id  \
# 71             72                                              NaN       100
# 109           110                                              NaN       100
# 296           297                                              NaN       100
# 416           417                                              NaN       100
# 436           437                                              NaN       100
# ...           ...                                              ...       ...
# 49689       49690                    HIGH PERFORMANCE ENERGY DRINK        64
# 49690       49691                    ORIGINAL PANCAKE & WAFFLE MIX       130
# 49691       49692  ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR       130
# 49692       49693                           SPRING WATER BODY WASH       127
# 49693       49694                          BURRITO- STEAK & CHEESE        38
#
#        department_id
# 71                21
# ...

# %%
df_products[df_products['product_name'].isnull()] # Verifique os nomes de produtos duplicados que não estão faltando
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
#
# Não há linhas nem IDs de produtos duplicados, mas existem muitos nomes de produtos repetidos; a maioria dessas duplicações ocorre em valores ausentes (NaN).

# %% [markdown]
# ### DataFrame `departments`

# %%
df_departments.duplicated() # Verifique se há linhas completamente duplicadas
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# dtype: bool

# %%
df_departments['department_id'].duplicated()# Verifique apenas se há IDs dos produtos duplicados
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# Name: department_id, dtype: bool

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
#
# Não há informações duplicadas

# %% [markdown]
# ### DataFrame `aisles`

# %%
df_aisles.duplicated () # Verifique se há linhas completamente duplicadas
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 129    False
# 130    False
# 131    False
# 132    False
# 133    False
# Length: 134, dtype: bool

# %%
df_aisles['aisle_id'] .duplicated() # Verifique apenas se há IDs dos produtos duplicados
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 129    False
# 130    False
# 131    False
# 132    False
# 133    False
# Name: aisle_id, Length: 134, dtype: bool

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
#
# Não há linhas duplicadas.

# %% [markdown]
# ### DataFrame `order_products`

# %%
df_order_prod.duplicated() # Verifique se há linhas completamente duplicadas
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 4545002    False
# 4545003    False
# 4545004    False
# 4545005    False
# 4545006    False
# Length: 4545007, dtype: bool

# %%
df_order_prod[df_order_prod['add_to_cart_order'].duplicated()]
 # Verifique mais uma vez se há outros casos complicados de duplicados
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 2         2261212       26683                1.0          1
# 6          644579       12341                5.0          1
# 9          420019       23315                4.0          1
# 12         522547       40571               10.0          1
# 14        1961225       37553                1.0          1
# ...           ...         ...                ...        ...
# 4545002    577211       15290               12.0          1
# 4545003   1219554       21914                9.0          0
# 4545004    692640       47766                4.0          1
# 4545005    319435         691                8.0          1
# 4545006   1398151       28733                9.0          0
#
# [4544942 rows x 4 columns]

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
#
# A primeira formula mostra a informação que não temos linhas duplicadas.
# Mas olhando para cada coluna conseguimos identificar que tenhos informações nas colunas que estão duplicadas

# %% [markdown]
# ## Encontre e remova valores ausentes
#
#
# Ao processarmos valores duplicados, observamos que também temos valores ausentes que precisamos investigar nas seguintes colunas:
#
# *	A coluna `'product_name'` da tabela products.
# *	A coluna `'days_since_prior_order'` da tabela orders.
# *	A coluna `'add_to_cart_order'` da tabela order_products.

# %% [markdown]
# ### DataFrame `products`

# %%
df_products[df_products['product_name'].isnull()]# Encontre valores ausentes na coluna 'product_name'
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Descreva brevemente suas conclusões.
#
# Temos cerca de 1258 produtos com valores ausentes

# %%
df_products[df_products['product_name'].isnull()]['aisle_id'].unique()# Todos os nomes de produtos ausentes estão associados com o corredor de ID 100?
# Out:
# array([100])

# %% [markdown]
# Descreva brevemente suas conclusões.
#
# Sim, todos  os nomes de produtos ausentes estão associados com o corredor de ID 100

# %%
df_products[df_products['product_name'].isnull()]['department_id'].unique() # Todos os nomes de produtos ausentes estão associados com o departamento de ID 21?
# Out:
# array([21])

# %% [markdown]
# Descreva brevemente suas conclusões.
#
#  Sim, todos os nomes de produtos ausentes estão associados com o departamento de ID 21

# %%
df_aisle_100 = df_aisles[df_aisles['aisle_id'] == 100]
print(df_aisle_100)


df_department_21 = df_departments[df_departments['department_id'] == 21]
print(df_department_21)

# Use as tabelas department e aisle para verificar os dados do corredor com ID 100 e do departamento com ID 21.
# Out:
#     aisle_id    aisle
# 99       100  missing
#     department_id department
# 20             21    missing

# %% [markdown]
# Descreva brevemente suas conclusões.
#
# Pelo resultado ter dado "missing", significa que todos os produtos que estavam sem nome (NaN) foram cadastrados originalmente nesse corredor e departamento especiais, que servem para indicar valores ausentes.

# %%
df_products['product_name'] = df_products['product_name'].fillna('Unknown')# Preencha nomes de produtos ausentes com 'Unknown'

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
#
# Analisamos o arquivo products e encontramos uma serie de informações faltanto da aba product_name, realizamos uma verificação nos outros arquivos para verificar se isso era verifico. Com essa confirmação, substituimos o NaN por Unknown para não termos valores ausentes

# %% [markdown]
# ### DataFrame `orders`

# %%
df_orders.isna() # Encontre os valores ausentes
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0          False    False         False      False              False
# 1          False    False         False      False              False
# 2          False    False         False      False              False
# 3          False    False         False      False              False
# 4          False    False         False      False              False
# ...          ...      ...           ...        ...                ...
# 478962     False    False         False      False              False
# 478963     False    False         False      False              False
# 478964     False    False         False      False              False
# 478965     False    False         False      False              False
# 478966     False    False         False      False              False
#
#         days_since_prior_order
# 0                        False
# 1                        False
# ...

# %%
# Há valores ausentes para os clientes que não estão fazendo o primeiro pedido?

'Após verificar os dados com `df_orders.isnull().sum()`, **não foram encontrados valores ausentes (NaN)** em nenhuma das colunas do dataset.'
# Out:
# 'Após verificar os dados com `df_orders.isnull().sum()`, **não foram encontrados valores ausentes (NaN)** em nenhuma das colunas do dataset.'

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
#
# Os dados estão completos e não necessitam tratamento para valores ausentes.

# %% [markdown]
# ### DataFrame `order_products`

# %%
df_order_prod.isna() # Encontre os valores ausentes
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 0           False       False              False      False
# 1           False       False              False      False
# 2           False       False              False      False
# 3           False       False              False      False
# 4           False       False              False      False
# ...           ...         ...                ...        ...
# 4545002     False       False              False      False
# 4545003     False       False              False      False
# 4545004     False       False              False      False
# 4545005     False       False              False      False
# 4545006     False       False              False      False
#
# [4545007 rows x 4 columns]

# %%
# 
Quais são os valores mínimo e máximo dessa coluna?

#Essa aqui eu não entendi, que coluna ? 
 
print(f"Mínimo: {df_order_prod['order_id'].min()}")
print
(f"Máximo: {df_order_prod['order_id'].max()}")
# Out:
# Object `coluna` not found.
# Mínimo: 4
# 'Máximo: 3421079'

# %% [markdown]
# Descreva brevemente suas conclusões.
#
# Ter dos aquivos falando sobre produtos me deixou um pouco confusa, não sei se o que eu estou fazendo está com base no arquivo base.
#
# De toda forma fiz.
#
# O DataFrame order_products não possui valores ausentes em nenhuma coluna, o que indica que todas as informações sobre pedidos, produtos, ordem no carrinho e reordenações estão completas e consistentes. Não é necessário preencher ou remover dados faltantes.

# %%
missing_add_to_cart = df_order_prod[df_order_prod['add_to_cart_order'].isna()]

print (missing_add_to_cart)
# Salve todos os IDs dos pedidos com pelo menos um valor ausente em 'add_to_cart_order'
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 737       2449164        5068                NaN          0
# 9926      1968313       43867                NaN          0
# 14394     2926893       11688                NaN          0
# 16418     1717990        4142                NaN          0
# 30114     1959075       42828                NaN          1
# ...           ...         ...                ...        ...
# 4505662   1800005        7411                NaN          0
# 4511400   1633337         260                NaN          0
# 4517562    404157        9517                NaN          0
# 4534112   1673227       17835                NaN          0
# 4535739   1832957       17949                NaN          1
#
# [836 rows x 4 columns]

# %%
# Todos os pedidos com valores ausentes contêm mais de 64 produtos?
missing_add_to_cart = df_order_prod[df_order_prod['add_to_cart_order'].isna()]

# Agrupe os pedidos com dados ausentes por ID de pedido
missing_counts = missing_add_to_cart.groupby('order_id')['product_id'].count()

# Conte o número de 'product_id' em cada pedido e verifique o valor mínimo da contagem
min_products = missing_counts.min()

print(missing_add_to_cart)
print(missing_counts)
print(min_products)
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 737       2449164        5068                NaN          0
# 9926      1968313       43867                NaN          0
# 14394     2926893       11688                NaN          0
# 16418     1717990        4142                NaN          0
# 30114     1959075       42828                NaN          1
# ...           ...         ...                ...        ...
# 4505662   1800005        7411                NaN          0
# 4511400   1633337         260                NaN          0
# 4517562    404157        9517                NaN          0
# 4534112   1673227       17835                NaN          0
# 4535739   1832957       17949                NaN          1
#
# [836 rows x 4 columns]
# order_id
# 9310        1
# 61355      63
# 102236     31
# 129627      5
# 165801      6
#            ..
# 2999801     6
# 3125735    22
# 3308010    51
# 3347453     7
# 3383594     5
# ...

# %% [markdown]
# Descreva brevemente suas conclusões.

# %%
df_order_prod['add_to_cart_order'] = df_order_prod['add_to_cart_order'].fillna(999)

# Substitua valores ausentes na coluna 'add_to_cart_order' por 999 e converta a coluna para o tipo integer

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.

# %% [markdown]
# <div class="alert alert-success">
# <strong>Comentário do revisor v1</strong>
#
# Duplicados e ausentes de todos os dfs foram investigados e corrigidos conforme o roteiro proposto
# </div>

# %% [markdown]
# ## Conclusões
#
# Escreva aqui suas conclusões intermediárias da Etapa 2. Preparação de dados

# %% [markdown]
# # Etapa 3. Análise de dados
#
# Quando os dados estiverem processados ​​e prontos, execute a seguinte análise:

# %% [markdown]
# # [A] Fácil (é necessário concluir tudo para passar)
#
# 1.	Verifique se os valores nas colunas `'order_hour_of_day'` e `'order_dow'` na tabela `orders` fazem sentido (ou seja, os valores da coluna  `'order_hour_of_day'` variam de 0 a 23 e os da `'order_dow'` variam de 0 a 6).
# 2.	Crie um gráfico que mostre quantas pessoas fazem pedidos a cada hora do dia.
# 3.	Crie um gráfico que mostre em que dia da semana as pessoas fazem compras.
# 4.	Crie um gráfico que mostre quanto tempo as pessoas esperam até fazer seu próximo pedido e comente sobre os valores mínimo e máximo.

# %% [markdown]
# ### [A1] Verifique se os valores fazem sentido

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_orders = pd.read_csv('/datasets/instacart_orders.csv', sep=';')

print("Valores mínimo e máximo de order_hour_of_day:")
print(f"Mínimo: {df_orders['order_hour_of_day'].min()}")
print(f"Máximo: {df_orders['order_hour_of_day'].max()}")

print("\nValores mínimo e máximo de order_dow:")
print(f"Mínimo: {df_orders['order_dow'].min()}")
print(f"Máximo: {df_orders['order_dow'].max()}")

pedidos_hora = df_orders['order_hour_of_day'].value_counts().sort_index()
pedidos_hora.plot(kind='bar', figsize=(10,6))
plt.title("Número de pedidos por hora do dia")
plt.xlabel("Hora do dia")
plt.ylabel("Quantidade de pedidos")
plt.show()

pedidos_semana = df_orders['order_dow'].value_counts().sort_index()
pedidos_semana.plot(kind='bar', figsize=(10,6))
plt.title("Dia da semana as pessoas fazem compras")
plt.xlabel("Dia da Semana")
plt.ylabel("Quantidade de pedidos")
plt.show()

espera = df_orders['days_since_prior_order'].value_counts().sort_index()
espera.plot(kind='bar', figsize=(10,6))
plt.title("Tempo de espera até o próximo pedido")
plt.xlabel("Dias de espera")
plt.ylabel("Quantidade de pedidos")
plt.show()
# Out:
# Valores mínimo e máximo de order_hour_of_day:
# Mínimo: 0
# Máximo: 23
#
# Valores mínimo e máximo de order_dow:
# Mínimo: 0
# Máximo: 6

# %%
'Os maiores picos são das 10h ás 17h'
'Maior volume de compra é domingo e segunda'
'A maioria dos cliente esperam 1 mês para fazer um novo pedido'
# Out:
# 'A maioria dos cliente esperam 1 mês para fazer um novo pedido'

# %% [markdown]
# Escreva suas conclusões aqui

# %% [markdown]
# ### [A2] Quantas pessoas fazem pedidos a cada hora do dia?

# %% [markdown]
# Madrugada (0h–5h) → quase não há pedidos.
#
# A partir das 6h → os pedidos começam a subir.
#
# Entre 9h e 16h → acontece o maior volume, com destaque para 10h e 11h, que chegam a mais de 40 mil pedidos cada.
#
# Após 17h → os pedidos começam a cair progressivamente.
#
# À noite (20h–23h) → ainda há uma quantidade relevante, mas bem menor do que no pico.
#
# Conclusão: A maior parte dos pedidos é feita durante o dia, principalmente entre 9h e 16h, com pico às 10h e 11h. Já de madrugada quase não há movimentação.

# %% [markdown]
# ### [A3] Em que dia da semana as pessoas compram produtos alimentícios?

# %% [markdown]
# Os maiores volumes de compras acontecem no domingo e na segunda, ambos acima de 80 mil pedidos.
#
# A partir da terça os números caem, ficando entre 60–66 mil pedidos até o sábado.
#
# O menor movimento é na quarta-feira .
#
# Conclusão: As pessoas compram mais no domingo e segunda-feira, enquanto o menor volume de pedidos ocorre no meio da semana, especialmente na quarta-feira.

# %% [markdown]
# ### [A4] Quanto tempo as pessoas esperam até fazer outro pedido?

# %% [markdown]
# A primeira semana do mês é de fato a que possue uma volume de venda mais constante.
# E finalizamos o mês com o dia 30 tendo a maior indice de compra.
#
# Conclusão: A maior parte dos clientes faz pedidos semanalmente (7 dias), mas também há muitos que repetem compras no dia seguinte ou esperam até 30 dias, sugerindo perfis diferentes de consumo (diário, semanal e mensal).

# %% [markdown]
# <div class="alert alert-success">
# <strong>Comentário do revisor v1</strong>
#
# Valores das colunas de dias e horas validados adequadamente.
# </div>
#
#
#
# <div class="alert alert-success">
# <strong>Comentário do revisor v1</strong>
#
# Pedidos ao longo do dia investigados adequadamente.
# </div>
#
#
#
# <div class="alert alert-success">
# <strong>Comentário do revisor v1</strong>
#
# Pedidos diários investigados adequadamente.
# </div>
#
#
# <div class="alert alert-success">
# <strong>Comentário do revisor v1</strong>
#
# Tempo entre pedidos foi devidamente investigado.
# </div>

# %% [markdown]
# # [B] Médio (é necessário concluir tudo para passar)
#
# 1.	Há alguma diferença nas distribuições de `'order_hour_of_day'` nas quartas e sábados? Construa gráficos de barras para ambos os dias no mesmo gráfico e descreva as diferenças que você notou.
# 2.	Construa um gráfico de distribuição para o número de pedidos que os clientes fazem (ou seja, quantos clientes fizeram apenas 1 pedido, quantos fizeram apenas 2, quantos apenas 3, etc.)
# 3.	Quais são os 20 produtos comprados com mais frequência? Exiba os IDs e nomes.

# %%
quartas = df_orders[df_orders['order_dow'] == 3]
sabados = order_productsorder_products[df_orders['order_dow'] == 6]

quartas_horas = quartas['order_hour_of_day'].value_counts().sort_index()
sabados_horas = sabados['order_hour_of_day'].value_counts().sort_index()

plt.figure(figsize=(10,6))
plt.bar(quartas_horas.index, quartas_horas.values, alpha=0.6, label="Quartas")
plt.bar(sabados_horas.index, sabados_horas.values, alpha=0.6, label="Sábados")
plt.xlabel("Hora do dia")
plt.ylabel("Quantidade de pedidos")
plt.title("Distribuição de pedidos por hora do dia (Quartas vs Sábados)")
plt.legend()
plt.show()

# %% [markdown]
# O volume de venda de ambos os dias são semelhantes, porém sabado continua tenta um certo voluma amais comparado a quarta. Dependente do horario, cada dia tem seu pico maior em relação ao outro.

# %% [markdown]
# <div class="alert alert-success">
# <strong>Comentário do revisor v1</strong>
#
# Ótimo, comparativo entre os dias foi conduzido com gráfico e conclusão de acordo com o esperado.
# </div>

# %% [markdown]
# ### [B2] Qual é a distribuição do número de pedidos por cliente?

# %%
orders_per_customer = df_orders.groupby('user_id')['order_number'].max()  
orders_distribution = orders_per_customer.value_counts().sort_index()

plt.figure(figsize=(10,6))
plt.bar(orders_distribution.index, orders_distribution.values, color='skyblue')
plt.title('Distribuição do número de pedidos por cliente')
plt.xlabel('Número de Pedidos')
plt.ylabel('Número de Clientes')
plt.show()

# %% [markdown]
# Em resumo, muitos clientes compram pouco e poucos clientes compram muito.

# %% [markdown]
# <div class="alert alert-success">
# <strong>Comentário do revisor v1</strong>
#
# Distribuição dos pedidos por clientes avaliada
# </div>

# %% [markdown]
# ### [B3] Quais são os 20 produtos mais populares? Exiba os IDs e nomes.

# %%
df_order_prod   = pd.read_csv('/datasets/order_products.csv',sep=';')

product_counts = df_order_prod['product_id'].value_counts().reset_index()
product_counts.columns = ['product_id', 'order_count']

top_products = product_counts.merge(df_products, on='product_id')
top_products = top_products.sort_values('order_count', ascending=False).head(20)

print(top_products[['product_id','product_name','order_count']])
# Out:
#     product_id              product_name  order_count
# 0        24852                    Banana        66050
# 1        13176    Bag of Organic Bananas        53297
# 2        21137      Organic Strawberries        37039
# 3        21903      Organic Baby Spinach        33971
# 4        47209      Organic Hass Avocado        29773
# 5        47766           Organic Avocado        24689
# 6        47626               Large Lemon        21495
# 7        16797              Strawberries        20018
# 8        26209                     Limes        19690
# 9        27845        Organic Whole Milk        19600
# 10       27966       Organic Raspberries        19197
# 11       22935      Organic Yellow Onion        15898
# 12       24964            Organic Garlic        15292
# 13       45007          Organic Zucchini        14584
# 14       39275       Organic Blueberries        13879
# 15       49683            Cucumber Kirby        13675
# ...

# %% [markdown]
# Os produtos mais vendidos são frutas, tendo banana como a maior venda.

# %% [markdown]
# <div class="alert alert-success">
# <strong>Comentário do revisor v1</strong>
#
# Produtos selecionados corretamente.
# </div>

# %% [markdown]
# # [C] Difícil (é necessário concluir pelo menos duas perguntas para passar)
#
# 1.	Quantos itens as pessoas normalmente compram em um pedido? Como fica a distribuição?
# 2.	Quais são os 20 principais itens incluídos mais frequentemente em pedidos repetidos? Exiba os IDs e nomes.
# 3.	Para cada produto, qual parcela de seus pedidos são repetidos? Crie uma tabela com colunas de ID e nome do produto e a proporção de pedidos repetidos.
# 4.	Para cada cliente, qual proporção de todos os seus pedidos são repetidos?
# 5.	Quais são os 20 principais itens que as pessoas colocam nos carrinhos antes de todos os outros? Exiba o ID do produto, nome e o número de vezes que ele foi o primeiro a ser adicionado a um carrinho.

# %% [markdown]
# ### [C1] Quantos itens as pessoas normalmente compram em um pedido? Como fica a distribuição?

# %%
itens_por_pedido = df_order_prod.groupby('order_id').size()
distribuicao = itens_por_pedido.value_counts().sort_index()

print("Distribuição de itens por pedido:")
print(distribuicao)

plt.figure(figsize=(10,6))
plt.bar(distribuicao.index, distribuicao.values, color='skyblue')
plt.title('Distribuição de itens em pedidos por cliente')
plt.xlabel('Número de Itens')
plt.ylabel('Número de Clientes')
plt.show()
# Out:
# Distribuição de itens por pedido:
# 1      21847
# 2      26292
# 3      29046
# 4      31054
# 5      31923
#        ...
# 98         1
# 104        1
# 108        1
# 115        1
# 127        1
# Length: 90, dtype: int64

# %% [markdown]
# A maioria dos clientes faz pedidos relativamente pequenos, mas há uma pequena proporção de pedidos grandes

# %% [markdown]
# <div class="alert alert-danger">
# <strong>Comentário do revisor v1</strong>
#
# Importante incluir uma visualização para essa questão.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <strong>Comentário do revisor v2</strong>
#
# Obrigado pelo ajuste!
# </div>

# %% [markdown]
# ### [C2] Quais são os 20 principais itens incluídos com mais frequência em pedidos repetidos? Exiba os IDs e nomes.

# %%
top_produtos = df_order_prod[df_order_prod['reordered'] == 1].groupby('product_id').size().reset_index(name='vezes_reordenado')
top20_produtos = top_produtos.sort_values('vezes_reordenado', ascending=False).head(20)

top20_produtos = top20_produtos.merge(df_products, on='product_id')

plt.figure(figsize=(12,8))
plt.bar(range(len(top20_produtos)), top20_produtos['vezes_reordenado'], color='skyblue')
plt.title('Top 20 Produtos Mais Reordenados')
plt.xlabel('Produtos')
plt.ylabel('Número de Reordenações')
plt.xticks(range(len(top20_produtos)), top20_produtos['product_name'], rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Alguns produtos são muito recorrentes, indicando que certos itens são preferidos pelos clientes e comprados regularmente.

# %% [markdown]
# <div class="alert alert-danger">
# <strong>Comentário do revisor v1</strong>
#
# Importante incluir o nome dos produtos selecionados.
# </div>

# %% [markdown]
# ### [C3] Para cada produto, qual parcela de todos os pedidos dele são repetidos?

# %%
proporcao_produto = df_order_prod.groupby('product_id')['reordered'].mean().reset_index()
proporcao_produto.rename(columns={'reordered':'proporcao_repetidos'}, inplace=True)
print("\nProporção de pedidos repetidos por produto:\n", proporcao_produto.head(20))
# Out:
# Proporção de pedidos repetidos por produto:
#      product_id  proporcao_repetidos
# 0            1             0.564286
# 1            2             0.000000
# 2            3             0.738095
# 3            4             0.510204
# 4            7             0.500000
# 5            8             0.315789
# 6            9             0.761905
# 7           10             0.448071
# 8           11             0.625000
# 9           12             0.390244
# 10          13             0.500000
# 11          14             0.000000
# 12          17             0.000000
# 13          18             0.533333
# 14          19             0.000000
# 15          21             0.000000
# 16          22             0.500000
# 17          23             0.380952
# 18          24             0.000000
# 19          25             0.674576

# %% [markdown]
# Certos produtos são itens de compra recorrente (necessários ou favoritos), enquanto outros são comprados apenas ocasionalmente

# %% [markdown]
# <div class="alert alert-success">
# <strong>Comentário do revisor v1</strong>
#
# Taxas calculadas corretamente.
# </div>

# %% [markdown]
# ### [C4] Para cada cliente, qual proporção de todos os seus pedidos são repetidos?

# %%
df_merged = df_order_prod.merge(df_orders[['order_id', 'user_id']], on='order_id')

pedido_repetido = df_merged.groupby(['user_id', 'order_id'])['reordered'].max().reset_index()
proporcao_cliente = pedido_repetido.groupby('user_id')['reordered'].mean().reset_index()
proporcao_cliente.rename(columns={'reordered':'proporcao_pedidos_repetidos'}, inplace=True)
print("\nProporção de pedidos repetidos por cliente:\n", proporcao_cliente.head(20))
# Out:
# Proporção de pedidos repetidos por cliente:
#      user_id  proporcao_pedidos_repetidos
# 0         2                     0.500000
# 1         4                     0.000000
# 2         5                     1.000000
# 3         6                     0.000000
# 4         7                     1.000000
# 5        11                     1.000000
# 6        12                     1.000000
# 7        13                     0.666667
# 8        14                     1.000000
# 9        15                     0.800000
# 10       16                     1.000000
# 11       17                     1.000000
# 12       19                     1.000000
# 13       20                     0.000000
# 14       21                     1.000000
# 15       22                     1.000000
# 16       24                     1.000000
# 17       26                     1.000000
# 18       27                     0.900000
# 19       28                     1.000000

# %% [markdown]
# Há perfis diferentes de clientes: alguns compram sempre os mesmos produtos, outros variam mais ou estão apenas experimentando a plataforma.

# %% [markdown]
# <div class="alert alert-success">
# <strong>Comentário do revisor v1</strong>
#
# Taxas calculadas corretamente.
# </div>

# %% [markdown]
# ### [C5] Quais são os 20 principais itens que as pessoas colocam nos carrinhos antes de todos os outros?

# %%
primeiros_itens = df_order_prod[df_order_prod['add_to_cart_order'] == 1]
top20_primeiros = primeiros_itens.groupby('product_id').size().reset_index(name='vezes_primeiro')
top20_primeiros = top20_primeiros.sort_values('vezes_primeiro', ascending=False).head(20)

print("\nTop 20 produtos adicionados primeiro ao carrinho:\n", top20_primeiros)

plt.figure(figsize=(12,8))
plt.bar(range(len(top20_primeiros)), top20_primeiros['vezes_primeiro'], color='skyblue')
plt.title('Top 20 principais itens primeiros escolhidos')
plt.xlabel('Produtos')
plt.ylabel('Número de vezes adicionado primeiro')
plt.xticks(range(len(top20_primeiros)), top20_primeiros['product_id'], rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Top 20 produtos adicionados primeiro ao carrinho:
#         product_id  vezes_primeiro
# 13414       24852           15562
# 7127        13176           11026
# 15028       27845            4363
# 11384       21137            3946
# 25439       47209            3390
# 11786       21903            3336
# 25732       47766            3044
# 10622       19660            2336
# 9050        16797            2308
# 15102       27966            2024
# 24024       44632            1914
# 26519       49235            1797
# 25658       47626            1737
# 115           196            1733
# 20853       38689            1397
# 14158       26209            1370
# 6660        12341            1340
# 3153         5785            1310
# 14639       27086            1309
# 23335       43352            1246

# %% [markdown]
# Alguns produtos são “preferenciais” e os clientes tendem a adicioná-los primeiro ao carrinho, possivelmente itens básicos ou favoritos.

# %% [markdown]
# <div class="alert alert-danger">
# <strong>Comentário do revisor v1</strong>
#
# Importante incluir o nome dos produtos selecionados.
# </div>

# %% [markdown]
# # Conclusão geral do projeto:

# %%
print("Analisamos o comportamento de compras dos clientes da Instacart, identificando horários, dias e padrões de repetição de pedidos. Produtos como frutas, especialmente bananas, são os mais vendidos e frequentemente repetidos. Os insights obtidos podem orientar estratégias de estoque, marketing e fidelização de clientes.")
# Out:
# Analisamos o comportamento de compras dos clientes da Instacart, identificando horários, dias e padrões de repetição de pedidos. Produtos como frutas, especialmente bananas, são os mais vendidos e frequentemente repetidos. Os insights obtidos podem orientar estratégias de estoque, marketing e fidelização de clientes.
